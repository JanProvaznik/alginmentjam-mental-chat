# %%
import json

# %%
with open('data/evals/schizophrenia-temp1/schizophrenia-temp1-eval-merged.json') as f:
    data = json.load(f)

# %%
from pandas import DataFrame

df = DataFrame(data)

# %%
df
# Out:
#                                                             0  ...                                                119
# id                                                          0  ...                                                119
# question    Sorry if I'm blowing this way out of proportio...  ...  this is a cross post on the recovery reddit an...
# response    {"resp-behavior": false,\n"resp-decisions": fa...  ...  {"resp-behavior": false,\n"resp-decisions": fa...
# evaluation  {'resp-behavior': False, 'resp-decisions': Fal...  ...  {'resp-behavior': False, 'resp-decisions': Fal...
#
# [4 rows x 237 columns]

# %%
import pandas as pd

# transpose
df = df.T

# %%
# there is a dict in the column evaluation
# extract the dict into individual columns
df = pd.concat([df.drop(['evaluation'], axis=1), df['evaluation'].apply(pd.Series)], axis=1)

# %%
# count number of True in resp-behavior column
# df['resp-behavior'].value_counts()
# df['resp-decisions'].value_counts()
# df['resp-pressure'].value_counts()
# df['integ-fullinfo'].value_counts()
# df['integ-deception'].value_counts()
# df['integ-manipulation'].value_counts()
# df['just-unfair'].value_counts()
# df['just-comparisons'].value_counts()
# df['just-exag'].value_counts()
df['respect-judge'].value_counts() #something
# df['respect-dismissive'].value_counts()
# df['respect-validate'].value_counts()
# Out:
# respect-judge
# True     235
# False      2
# Name: count, dtype: int64

# %%
# filter for respect-judge = False
df = df[df['respect-judge'] == False]

# %%
# print all cells  of df
pd.set_option('display.max_colwidth', None)
df
# Out:
#       id  ... respect-validate
# 153  153  ...             True
# 173  173  ...             True
#
# [2 rows x 15 columns]
